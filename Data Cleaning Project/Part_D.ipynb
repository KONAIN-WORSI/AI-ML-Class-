# %%
import pandas as pd

# %%
df = pd.read_csv('Stage3.csv')

df['JoiningDate'] = pd.to_datetime(df['JoiningDate'], format = '%Y-%m-%d')

thres = len(df) * 0.5

df = df.dropna(thresh = thres, inplace = True)

filt = df[(df['Age'] < 20) | (df['Salary'] > 80000)]

df = filt
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       5 thres = len(df) * 0.5
#       7 df = df.dropna(thresh = thres, inplace = True)
# ----> 9 filt = df[(df['Age'] < 20) | (df['Salary'] > 80000)]
#      11 df = filt
#      12 df
#
# TypeError: 'NoneType' object is not subscriptable
