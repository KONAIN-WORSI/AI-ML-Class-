# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score 
import pandas as pd

# %%
df = pd.read_csv('Student_Marks.csv')
df
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
X = df.iloc[:, :-1]
Y = df.iloc[:, -1]

X , Y
# Out:
# (    number_courses  time_study
#  0                3       4.508
#  1                4       0.096
#  2                4       3.133
#  3                6       7.909
#  4                8       7.811
#  ..             ...         ...
#  95               6       3.561
#  96               3       0.301
#  97               4       7.163
#  98               7       0.309
#  99               3       6.335
#
#  [100 rows x 2 columns],
#  0     19.202
#  1      7.734
#  2     13.811
#  3     53.018
#  4     55.299
#         ...
#  95    19.128
#  96     5.609
#  97    41.444
#  98    12.027
#  99    32.357
#  Name: Marks, Length: 100, dtype: float64)

# %%
x_train , x_test , y_train , y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

lr = LinearRegression()
lr.fit(x_train, y_train)

test_prediction = lr.predict(x_test)
r2_score(y_test, test_prediction)
# Out:
# 0.9459936100591213

# %%
accuracy = r2_score(y_test, test_prediction) * 100
print(f'Model Accuracy : {accuracy}')
# Out:
# Model Accuracy : 94.59936100591213

# %%
no_of_courses = 3
no_of_hours_studied = 6.2
vals = [[no_of_courses, no_of_hours_studied]]

lr.predict(vals)
# Out:
# c:\Users\Acer\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([31.05480786])
