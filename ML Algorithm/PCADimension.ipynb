# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
X, y_true = make_blobs(n_samples=500, n_features=5, centers=3, cluster_std=1.5, random_state=42)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
df = pd.DataFrame(X_pca, columns=['PC_1', 'PC_2'])
df['label'] = y_true

# %%
sns.scatterplot(data=df, x='PC_1', y='PC_2', hue='label', palette='Set2')
# Out:
# <Axes: xlabel='PC_1', ylabel='PC_2'>
